# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read a comma-separated values (csv) file into DataFrame.
#
# The data folder contains a file named "newark_tree_data.csv". Read this file into a dataframe.
#
#
# resources:
# * [Pandas read csv docs](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)

# %%
# Create DataFrame here.
df = pd.read_csv('data/newark_tree_data.csv')

# %%
# Display the first few rows of the DataFrame here.
df.head()
# Out:
#      ID         ON       AREA  ADDRESS       STREET  SITE   SIDE  ASSIGNED  \
# 0  11.0  Elan Park  Elan Park        2  Blue Hen Rg  11.0  Front     False
# 1  12.0  Elan Park  Elan Park        2  Blue Hen Rg  12.0  Front     False
# 2  13.0  Elan Park  Elan Park        2  Blue Hen Rg  13.0  Front     False
# 3  14.0  Elan Park  Elan Park        2  Blue Hen Rg  14.0  Front     False
# 4  15.0  Elan Park  Elan Park        2  Blue Hen Rg  15.0  Front     False
#
#                  COMMON               BOTANICAL  ... IMPROPMULC  IMPROPPRUN  \
# 0   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 1   arborvitae, eastern      Thuja occidentalis  ...      False       False
# 2   pine, eastern white           Pinus strobus  ...      False       False
# 3  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
# 4  whitecedar, Atlantic  Chamaecyparis thyoides  ...      False       False
#
#   NUTRIENTD   PEST GIRDLING STRESS  OHUTILITY  TOP_HEIGHT CROWN_M CROWN_DIE
# 0     False  False    False  False         No          40    0-5%      0-5%
# 1     False  False    False  False         No          41    0-5%      0-5%
# 2     False  False     True  False         No          54    0-5%     6-10%
# 3     False  False     True  False         No          57  11-15%    26-30%
# 4     False  False     True  False         No          55  11-15%    21-25%
#
# [5 rows x 54 columns]

# %%
# How many columns does the DataFrame contain?
df.shape
# Out:
# (4193, 54)

# %% [markdown]
# 54 columns, df.shape gives rows by columns in a dataframe, at least with csv or polygon (rectangle) data?

# %%
# What attributes (columns) does this DataFrame contain?
df.columns
# Out:
# Index(['ID', 'ON', 'AREA', 'ADDRESS', 'STREET', 'SITE', 'SIDE', 'ASSIGNED',
#        'COMMON', 'BOTANICAL', 'CULTIVAR', 'DBH', 'REMOVAL', 'STEMS', 'COND',
#        'MAINTPRIM', 'OBSERVE', 'INSPECT', 'LOCATION', 'NOTES', 'DATE', 'TIME',
#        'STAFF', 'XCOORD', 'YCOORD', 'FAILURE', 'LIKELIHOOD', 'TARGET',
#        'CONSEQ', 'RISK', 'UNIQUEID', 'EDITTIME', 'SPREAD', 'HEIGHT',
#        'CLEARANCE', 'DECAYCL', 'DECAYT', 'DECAYRF', 'DAMC', 'DAMT', 'DAMRF',
#        'CAVITYCL', 'CAVITYT', 'CAVITYRF', 'IMPROPMULC', 'IMPROPPRUN',
#        'NUTRIENTD', 'PEST', 'GIRDLING', 'STRESS', 'OHUTILITY', 'TOP_HEIGHT',
#        'CROWN_M', 'CROWN_DIE'],
#       dtype='object')

# %% [markdown]
# Upon reviewing the columns of the DataFrame, we see that there is already a column named ID that is well suited for an index column.
#
# For the purposes of this lab, we are only going to need a few of the available attributes. The attributes we wish to keep are listed below:
# * ID
# * UNIQUEID
# * COMMON
# * BOTANICAL
# * COND
# * RISK
# * HEIGHT
#
# Let's provide the index_col and the usecols args when we invoke the read_csv method.

# %%
# Create the new DataFrame here.
df2 = pd.read_csv('data/newark_tree_data.csv', usecols=["ID", "UNIQUEID", "COMMON", "BOTANICAL", "COND", "RISK", "HEIGHT"])
df2 = df2.set_index("ID")

# %%
# Display the first few rows of the new DataFrame here.
df2.head(30)
# Out:
#                     COMMON                BOTANICAL       COND      RISK  \
# ID
# 11.0   arborvitae, eastern       Thuja occidentalis       Good       Low
# 12.0   arborvitae, eastern       Thuja occidentalis  Very Good       Low
# 13.0   pine, eastern white            Pinus strobus       Good       Low
# 14.0  whitecedar, Atlantic   Chamaecyparis thyoides       Fair       Low
# 15.0  whitecedar, Atlantic   Chamaecyparis thyoides       Fair       Low
# 16.0   pine, eastern white            Pinus strobus       Fair       Low
# 17.0  whitecedar, Atlantic   Chamaecyparis thyoides       Fair       Low
# 18.0   pine, eastern white            Pinus strobus       Fair       Low
# 19.0   arborvitae, eastern       Thuja occidentalis       Fair       Low
# 20.0   arborvitae, eastern       Thuja occidentalis       Fair       Low
# 21.0   arborvitae, eastern       Thuja occidentalis       Good       Low
# 22.0   arborvitae, eastern       Thuja occidentalis       Fair       Low
# 23.0   arborvitae, eastern       Thuja occidentalis       Fair       Low
# 24.0   arborvitae, eastern       Thuja occidentalis       Fair       Low
# 25.0   pine, eastern white            Pinus strobus  Very Good       Low
# 1.0          locust, black     Robinia pseudoacacia       Poor  Moderate
# 2.0           elm, Chinese         Ulmus parvifolia       Good       Low
# 3.0     sweetgum, American  Liquidambar styraciflua       Good       Low
# 4.0           maple, sugar           Acer saccharum       Fair  Moderate
# 5.0           maple, sugar           Acer saccharum       Fair       Low
# 6.0              tuliptree  Liriodendron tulipifera       Fair       Low
# 7.0    arborvitae, eastern       Thuja occidentalis       Good       Low
# 8.0    arborvitae, eastern       Thuja occidentalis  Very Good       Low
# 9.0    arborvitae, eastern       Thuja occidentalis       Good       Low
# 10.0   arborvitae, eastern       Thuja occidentalis  Very Good       Low
# 26.0   pine, eastern white            Pinus strobus       Fair       Low
# 27.0          elm, Chinese         Ulmus parvifolia       Good       Low
# 28.0     zelkova, Japanese          Zelkova serrata       Good       Low
# 29.0     zelkova, Japanese          Zelkova serrata       Fair       Low
# 30.0     zelkova, Japanese          Zelkova serrata       Good       Low
#
#                UNIQUEID  HEIGHT
# ID
# 11.0  LM 20150929141218      40
# 12.0  LM 20150929141418      40
# 13.0  LM 20150929141844      54
# 14.0  LM 20150929142424      56
# 15.0  LM 20150929143018      55
# 16.0  LM 20150929143352      55
# 17.0  LM 20150929143905      55
# 18.0  LM 20150929144155      55
# 19.0  LM 20150929144438      55
# 20.0  LM 20150929144602      55
# 21.0  LM 20150929144817      55
# 22.0  LM 20150929144951      55
# 23.0  LM 20150929145226      55
# 24.0  LM 20150929145426      55
# 25.0  LM 20150929150510      39
# 1.0   LM 20150929131426      43
# 2.0   LM 20150929132329      37
# 3.0   LM 20150929133307      77
# 4.0   LM 20150929133918      71
# 5.0   LM 20150929134724      68
# 6.0   LM 20150929135604      80
# 7.0   LM 20150929140115      25
# 8.0   LM 20150929140537      30
# 9.0   LM 20150929140718      30
# 10.0  LM 20150929140909      40
# 26.0  LM 20150929150902      31
# 27.0  LM 20150929151242      54
# 28.0  LM 20150929151659      33
# 29.0  LM 20150929152025      37
# 30.0  LM 20150929152532      45

# %% [markdown]
# The data narritive specifies that 4,193 sites were inventoried. Use the DataFrame shape attribute to verify the number of rows.

# %%
df2.tail(30)
# Out:
#                       COMMON                BOTANICAL       COND      RISK  \
# ID
# 4164.0            yellowwood      Cladrastis kentukea  Very Good       Low
# 4165.0       spruce, Serbian            Picea omorika       Poor       Low
# 4166.0       spruce, Serbian            Picea omorika       Good       Low
# 4167.0                 stump                    stump        NaN       NaN
# 4168.0                 stump                    stump        NaN       NaN
# 4169.0       spruce, Serbian            Picea omorika       Fair       Low
# 4170.0            yellowwood      Cladrastis kentukea       Good       Low
# 4171.0      hardy rubbertree        Eucommia ulmoides       Fair       Low
# 4172.0  lilac, Japanese tree       Syringa reticulata       Good       Low
# 4173.0       maple, Tatarian           Acer tataricum       Good       Low
# 4174.0       maple, Tatarian           Acer tataricum       Good       Low
# 4175.0                 stump                    stump        NaN       NaN
# 4176.0         oak, sawtooth       Quercus acutissima       Fair       Low
# 4177.0         oak, sawtooth       Quercus acutissima       Good       Low
# 4178.0   Japanese pagodatree  Styphnolobium japonicum       Fair  Moderate
# 4179.0         oak, sawtooth       Quercus acutissima  Very Good       Low
# 4180.0   Japanese pagodatree  Styphnolobium japonicum       Good       Low
# 4181.0         oak, sawtooth       Quercus acutissima  Very Good       Low
# 4182.0   Japanese pagodatree  Styphnolobium japonicum       Good       Low
# 4183.0         oak, sawtooth       Quercus acutissima       Good       Low
# 4184.0   Japanese pagodatree  Styphnolobium japonicum       Good       Low
# 4185.0         oak, sawtooth       Quercus acutissima       Good       Low
# 4186.0   Japanese pagodatree  Styphnolobium japonicum       Good       Low
# 4187.0   Japanese pagodatree  Styphnolobium japonicum       Poor  Moderate
# 4188.0         oak, sawtooth       Quercus acutissima       Fair  Moderate
# 4189.0   Japanese pagodatree  Styphnolobium japonicum       Good       Low
# 4190.0         oak, sawtooth       Quercus acutissima       Good       Low
# 4191.0   Japanese pagodatree  Styphnolobium japonicum       Fair       Low
# 4192.0    sycamore, American    Platanus occidentalis       Good       Low
# 4193.0            ash, white       Fraxinus americana       Fair       Low
#
#                  UNIQUEID  HEIGHT
# ID
# 4164.0  SR 20151104142251      30
# 4165.0  SR 20151104142426      30
# 4166.0  SR 20151104142534      60
# 4167.0  SR 20151104142636       0
# 4168.0  SR 20151104142704       0
# 4169.0  SR 20151104142757      65
# 4170.0  SR 20151104142931      25
# 4171.0  SR 20151104143030      30
# 4172.0  SR 20151104143144      30
# 4173.0  SR 20151104143245      25
# 4174.0  SR 20151104143348      25
# 4175.0  SR 20151104151721       0
# 4176.0  SR 20151104151838      40
# 4177.0  SR 20151104152015      45
# 4178.0  SR 20151104152233      40
# 4179.0  SR 20151104152440      50
# 4180.0  SR 20151104152530      45
# 4181.0  SR 20151104152634      50
# 4182.0  SR 20151104152724      45
# 4183.0  SR 20151104152827      55
# 4184.0  SR 20151104152918      45
# 4185.0  SR 20151104153015      55
# 4186.0  SR 20151104153101      45
# 4187.0  SR 20151104153200      45
# 4188.0  SR 20151104153330      55
# 4189.0  SR 20151104153437      50
# 4190.0  SR 20151104153555      55
# 4191.0  SR 20151104153647      45
# 4192.0  SR 20151104160909      80
# 4193.0  SR 20151104161140      70

# %%
# How many rows does your DataFrame contain.
df2.shape
# Out:
# (4193, 6)

# %% [markdown]
# Let's look at the distribution of data for the HEIGHT attribute.

# %%
# What is the min height?
df2["HEIGHT"].min()
# Out:
# 0

# %%
# What is the max height?
df2["HEIGHT"].max()
# Out:
# 140

# %%
# How do we acquire count, mean, standard deviation, and distribution information from the DataFrame 
# by invoking a single method?
df2.describe()
# Out:
#             HEIGHT
# count  4193.000000
# mean     55.311472
# std      36.293489
# min       0.000000
# 25%      23.000000
# 50%      50.000000
# 75%      86.000000
# max     140.000000

# %% [markdown]
# # Plot a histogram using the HEIGHT attribute.
#
# resources:
# * [Magic commands](https://ipython.readthedocs.io/en/stable/interactive/magics.html)
# * [Pandas Series Hist](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.hist.html#pandas.Series.plot.hist)

# %%
# Apply magic command to display matplotlib images inline
# %matplotlib inline

# %%
# Create a histogram using the HEIGHT attribute here
ax = df2["HEIGHT"].plot.hist(bins=10)

# %%
ax2 = df2.plot.hist(column=["HEIGHT"], bins=10)

# %% [markdown]
# The data narrative specifies the following:
# "A total of 4,193 sites were inventoried, including 4,087 trees, 100 stumps, and 6 vacant planting sites"
#
# Earlier, we were able to validate the total number of entries in the DataFrame. Let's now dig in a bit deeper and validate the stumps and vacant planting sites.

# %%
# How many entries are stumps
df3 = df2.loc[df2["COMMON"]=="stump"]
df3
# Out:
#        COMMON BOTANICAL COND RISK           UNIQUEID  HEIGHT
# ID
# 119.0   stump     stump  NaN  NaN  LM 20151001093501       0
# 120.0   stump     stump  NaN  NaN  LM 20151001093612       0
# 269.0   stump     stump  NaN  NaN  LM 20151005101319       0
# 270.0   stump     stump  NaN  NaN  LM 20151005101403       0
# 271.0   stump     stump  NaN  NaN  LM 20151005101436       0
# ...       ...       ...  ...  ...                ...     ...
# 4095.0  stump     stump  NaN  NaN  SR 20151103154447       0
# 4149.0  stump     stump  NaN  NaN  SR 20151104115722       0
# 4167.0  stump     stump  NaN  NaN  SR 20151104142636       0
# 4168.0  stump     stump  NaN  NaN  SR 20151104142704       0
# 4175.0  stump     stump  NaN  NaN  SR 20151104151721       0
#
# [100 rows x 6 columns]

# %%
# Count the columns is another way to get stumps, I think this will work
test_series = df2["COMMON"]
stumps_bool = (test_series == "stump")
print(stumps_bool.sum())
# Out:
# 100

# %% [markdown]
# ### To find the vacant lots, might need to look at botanical column

# %%
df2["BOTANICAL"].unique()
# Out:
# array(['Thuja occidentalis', 'Pinus strobus', 'Chamaecyparis thyoides',
#        'Robinia pseudoacacia', 'Ulmus parvifolia',
#        'Liquidambar styraciflua', 'Acer saccharum',
#        'Liriodendron tulipifera', 'Zelkova serrata', 'Quercus rubra',
#        'Quercus prinus', 'Pinus thunbergii', 'Salix nigra',
#        'Nyssa aquatica', 'Platanus x acerifolia', 'Crataegus spp.',
#        'Phellodendron amurense', 'Cornus kousa', 'Fraxinus americana',
#        'Quercus spp.', 'Acer saccharinum', 'Maclura pomifera',
#        'Quercus palustris', 'Acer rubrum', 'Platanus occidentalis',
#        'Quercus phellos', 'Juniperus spp.', 'Acer negundo',
#        'Taxodium ascendens', 'Betula nigra', 'Quercus alba',
#        'Carya glabra', 'stump', 'Cornus florida', 'Carya tomentosa',
#        'Quercus bicolor', 'Syringa reticulata', 'Hamamelis virginiana',
#        'Quercus acutissima', 'Juglans nigra', 'Prunus spp.', 'Ilex opaca',
#        'Picea glauca', 'Elaeagnus angustifolia', 'Amelanchier laevis',
#        'Cercis canadensis', 'Picea abies', 'Magnolia stellata',
#        'Cedrus atlantica', 'Cedrus deodara', 'Pinus cembra',
#        'Picea pungens', 'Cryptomeria japonica', 'Tsuga caroliniana',
#        'Ostrya japonica', 'Parrotia persica', 'Magnolia spp.',
#        'Prunus serotina', 'Carya cordiformis', 'unknown tree',
#        'Quercus falcata', 'Lagerstroemia indica', 'Fraxinus caroliniana',
#        'Metasequoia glyptostroboides', 'Acer platanoides', 'Pinus taeda',
#        'Catalpa speciosa', 'Pinus virginiana', 'Koelreuteria paniculata',
#        'Chamaecyparis spp.', 'Cercidiphyllum japonicum',
#        'Cunninghamia lanceolata', 'Morus alba', 'Acer nigrum',
#        'Malus spp.', 'Ilex cornuta', 'Paulownia tomentosa',
#        'Fraxinus pennsylvanica', 'Lonicera spp.', 'Taxodium distichum',
#        'Magnolia virginiana', 'Ulmus americana', 'Acer tataricum ginnala',
#        'Quercus stellata', 'Sassafras albidum', 'Cladrastis kentukea',
#        'Halesia tetraptera', 'Gymnocladus dioicus', 'Tilia cordata',
#        'Magnolia tripetala', 'Pinus nigra', 'Carya spp.',
#        'Fagus grandifolia', 'Quercus coccinea', 'Quercus velutina',
#        'Pseudotsuga menziesii', 'Gleditsia triacanthos inermis',
#        'Pterocarya fraxinifolia', 'Taxus spp.', 'Fagus sylvatica',
#        'Tsuga candensis', 'Styphnolobium japonicum',
#        'Magnolia x soulangiana', 'Carpinus caroliniana', 'Hovenia dulcis',
#        'Ailanthus altissima', 'Chionanthus retusus', 'Abies balsamea',
#        'Acer palmatum', 'Juniperus virginiana', 'Elaeagnus umbellata',
#        'Diospyros virginiana', 'Rhamnus cathartica', 'Nyssa sylvatica',
#        'Amelanchier canadensis', 'Albizia julibrissin',
#        'Prunus serrulata', 'Castanea mollissima',
#        'X Cupressocyparis leylandii', 'Thuja spp.', 'Morus rubra',
#        'Magnolia grandiflora', 'Gleditsia triacanthos',
#        'Aesculus x carnea', 'Quercus margaretta', 'Aesculus flava',
#        'Ginkgo biloba', 'Pyrus calleryana', 'Salix spp.', 'Picea omorika',
#        'Celtis occidentalis', 'Franklinia alatamaha', 'Viburnum spp.',
#        'Cornus spp.', 'Styrax japonicus', 'Ulmus rubra',
#        'Prunus sargentii', 'Cotinus coggygria', 'Betula lenta',
#        'Acer griseum', 'Ochna serrulata', 'Amelanchier spp.',
#        'Manilkara roxburghiana', 'Carya laciniosa', 'Acer campestre',
#        'Quercus imbricaria', 'Alnus glutinosa', 'Cornus mas',
#        'Juglans regia', 'Pinus parviflora', 'vacant site large',
#        'Tilia americana', 'Picea rubens', 'Ulmus pumila', 'Ilex spp.',
#        'Tibouchina grandiflora', 'Acer tataricum', 'Eucommia ulmoides',
#        'Ulmus carpinifolia'], dtype=object)

# %%
# How many entries are vacant sites
df4 = df2.loc[df2["BOTANICAL"].str.contains("vacant")]
df4
# Out:
#                     COMMON          BOTANICAL COND RISK           UNIQUEID  \
# ID
# 3913.0  vacant site, large  vacant site large  NaN  NaN  SR 20151031122829
# 3922.0  vacant site, large  vacant site large  NaN  NaN  SR 20151031125116
# 3939.0  vacant site, large  vacant site large  NaN  NaN  SR 20151031132401
# 3941.0  vacant site, large  vacant site large  NaN  NaN  SR 20151031133111
# 3946.0  vacant site, large  vacant site large  NaN  NaN  SR 20151031133520
# 3947.0  vacant site, large  vacant site large  NaN  NaN  SR 20151031133542
#
#         HEIGHT
# ID
# 3913.0       0
# 3922.0       0
# 3939.0       0
# 3941.0       0
# 3946.0       0
# 3947.0       0

# %%
# I believe this is a way to get the count once we know the string we are looking for
test_series = df2["BOTANICAL"]
vacant_bool = test_series.str.contains("vacant")
print(vacant_bool.sum())
# Out:
# 6

# %% [markdown]
# #### Do these number add up?
# Yes, 100 rows and 6 rows, with identifying strings in commone and botanical as stumps or vacant sites.

# %%
if (stumps_bool.sum() + vacant_bool.sum()) == 106:
    print("Expected number of stumps and vacant lots")
else:
    print("Mismatched counts")
# Out:
# Expected number of stumps and vacant lots

# %% [markdown]
# # Plot a bar graph using the COND attribute.
#
# resources:
# * [Pandas Series Bar](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.bar.html#pandas.Series.plot.bar)

# %%
# How can we determine all of the possible values describing the condition of a tree and their associated counts?
conditions = df2["COND"]
conditions.unique()
# Out:
# array(['Good', 'Very Good', 'Fair', 'Poor', 'Dead', 'Critical', nan,
#        'Very Poor', 'Excellent'], dtype=object)

# %%
# How can we determine all of the possible values describing the condition of a tree and their associated counts?
conditions.value_counts()
# Out:
# COND
# Fair         1598
# Good         1168
# Poor          402
# Very Good     381
# Dead          218
# Excellent     163
# Very Poor      83
# Critical       74
# Name: count, dtype: int64

# %%
# Were these already in the order you would want them to be in order for a graph to make sense? 
# If not, reorder  the Series.

# I'm struggling with how to do this.  I'm guessing I can make a dictionary to give a ranking to each condititon first.
index_dict = {'Excellent': 0, 'Very Good': 1, 'Good': 2, 'Fair': 3, 'Poor': 4, 'Very Poor': 5, 'Critical': 6,
                'Dead' : 7}

# Map that into my datafram so each conditoin has a numeric value for sorting, alphabetical won't work
df2["rank"] = df2["COND"].map(index_dict)
df2
# Out:
#                       COMMON                BOTANICAL       COND RISK  \
# ID
# 11.0     arborvitae, eastern       Thuja occidentalis       Good  Low
# 12.0     arborvitae, eastern       Thuja occidentalis  Very Good  Low
# 13.0     pine, eastern white            Pinus strobus       Good  Low
# 14.0    whitecedar, Atlantic   Chamaecyparis thyoides       Fair  Low
# 15.0    whitecedar, Atlantic   Chamaecyparis thyoides       Fair  Low
# ...                      ...                      ...        ...  ...
# 4189.0   Japanese pagodatree  Styphnolobium japonicum       Good  Low
# 4190.0         oak, sawtooth       Quercus acutissima       Good  Low
# 4191.0   Japanese pagodatree  Styphnolobium japonicum       Fair  Low
# 4192.0    sycamore, American    Platanus occidentalis       Good  Low
# 4193.0            ash, white       Fraxinus americana       Fair  Low
#
#                  UNIQUEID  HEIGHT  rank
# ID
# 11.0    LM 20150929141218      40   2.0
# 12.0    LM 20150929141418      40   1.0
# 13.0    LM 20150929141844      54   2.0
# 14.0    LM 20150929142424      56   3.0
# 15.0    LM 20150929143018      55   3.0
# ...                   ...     ...   ...
# 4189.0  SR 20151104153437      50   2.0
# 4190.0  SR 20151104153555      55   2.0
# 4191.0  SR 20151104153647      45   3.0
# 4192.0  SR 20151104160909      80   2.0
# 4193.0  SR 20151104161140      70   3.0
#
# [4193 rows x 7 columns]

# %%
# Now I will sort the entire data frame by the ranking I created, in place and with the nan in last
df5 = df2.sort_values(by="rank", na_position='last', ignore_index=True)
df5
# Out:
#                    COMMON             BOTANICAL       COND RISK  \
# 0         hickory, pignut          Carya glabra  Excellent  Low
# 1       redcedar, eastern  Juniperus virginiana  Excellent  Low
# 2     crapemyrtle, common  Lagerstroemia indica  Excellent  Low
# 3       redcedar, eastern  Juniperus virginiana  Excellent  Low
# 4     arborvitae, eastern    Thuja occidentalis  Excellent  Low
# ...                   ...                   ...        ...  ...
# 4188                stump                 stump        NaN  NaN
# 4189                stump                 stump        NaN  NaN
# 4190                stump                 stump        NaN  NaN
# 4191                stump                 stump        NaN  NaN
# 4192                stump                 stump        NaN  NaN
#
#                UNIQUEID  HEIGHT  rank
# 0     SR 20151006104051       7   0.0
# 1     SR 20151015151753      15   0.0
# 2     SR 20151008144159      15   0.0
# 3     SR 20151015151355      15   0.0
# 4     SR 20151102163447      20   0.0
# ...                 ...     ...   ...
# 4188  SR 20151103154447       0   NaN
# 4189  SR 20151104115722       0   NaN
# 4190  SR 20151104142636       0   NaN
# 4191  SR 20151104142704       0   NaN
# 4192  SR 20151104151721       0   NaN
#
# [4193 rows x 7 columns]

# %%
# So this is now looking like the order of data I want
sorted_conditions = pd.Series(df5["COND"].values, df5["rank"])
sorted_conditions
# Out:
# rank
# 0.0    Excellent
# 0.0    Excellent
# 0.0    Excellent
# 0.0    Excellent
# 0.0    Excellent
#          ...
# NaN          NaN
# NaN          NaN
# NaN          NaN
# NaN          NaN
# NaN          NaN
# Length: 4193, dtype: object

# %%
s_5 = sorted_conditions.value_counts(sort=False, dropna=False)
s_5
# Out:
# Excellent     163
# Very Good     381
# Good         1168
# Fair         1598
# Poor          402
# Very Poor      83
# Critical       74
# Dead          218
# NaN           106
# Name: count, dtype: int64

# %% [markdown]
# I am struggling so much with sorting and plotting in sorted order.

# %%
# Plot the Series here
ax5 = s_5.plot.bar()

# %%
# How many entries have missing values for the COND attribute? Why are these values missing?
some amount

# %% [markdown]
# # Plot a pie chart using the RISK attribute.

# %% [markdown]
# resources:
# * [Pandas Series Pie](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.plot.pie.html#pandas.Series.plot.pie)
# * [matplotlib pie chart docs](https://matplotlib.org/api/pyplot_api.html#matplotlib.pyplot.pie)

# %%
# How can we determine all of the possible values describing the RISK associated with each tree
# along with the corresponding row counts?
risks = df2["RISK"]
risks.value_counts()

# %%
# Create an array containing the colors green, yellow, and orange
# When we create our pie chart, the colors should be associated with the attributes according to the specifications below:
# Green -> Low
# Yellow -> Moderate
# Orange -> High
no

# %%
# Plot the pie chart here
no

# %% [markdown]
# # How many entries have missing values for the RISK attribute? Why are these values missing?
# some amount.  Because of bad data entry and poor data integrity and usability for however the data was collected.

# %% [markdown]
# # Indexing

# %%
# Display row by position 1
no

# %%
# Display row by label 1
no
